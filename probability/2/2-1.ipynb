# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("2-1.csv")

plt.figure(figsize=(5, 5))

plt.scatter("n", "rnd", data=data, label="λ = 0.5", s=0.5)

plt.grid(True)

plt.show()
